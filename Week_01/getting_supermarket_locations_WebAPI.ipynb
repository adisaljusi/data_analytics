# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /Users/adisaljusi/repos/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3456, 276)
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.226191  8.980329         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode tags.addr:street tags.brand  ...  \
# 0                    32               8718   Biltnerstrasse       Spar  ...
# 1                    25               8730   Zürcherstrasse     Migros  ...
# 2                   NaN               8730              NaN       Coop  ...
# 3                     1               8001    Bahnhofbrücke       Coop  ...
# 4                     7               8004     Wengistrasse     Migros  ...
#
#   tags.postid tags.diet:local tags.payment:account_cards  \
# 0         NaN             NaN                        NaN
# 1         NaN             NaN                        NaN
# 2         NaN             NaN                        NaN
# 3         NaN             NaN                        NaN
# 4         NaN             NaN                        NaN
#
#   tags.diet:mediterranean tags.diet:organic tags.diet:seafood  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#   tags.recycling:low_energy_bulbs tags.image tags.opening_hours:cafe  \
# 0                             NaN        NaN                     NaN
# 1                             NaN        NaN                     NaN
# 2                             NaN        NaN                     NaN
# 3                             NaN        NaN                     NaN
# 4                             NaN        NaN                     NaN
#
#   tags.name:zh-Hans
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 276 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 6  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7db7e329654cb4f2b06e52ebff2604f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7db7e329654cb4f2b06e52ebff2604f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7db7e329654cb4f2b06e52ebff2604f4 = L.map(
#                 &quot;map_7db7e329654cb4f2b06e52ebff2604f4&quot;,
#                 {
#                     center: [47.00818312293046, 8.004441988493378],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7db7e329654cb4f2b06e52ebff2604f4);
#
#
#
#
#
#             var tile_layer_f5ed942d42d8e5338975a7849ab7adb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f5ed942d42d8e5338975a7849ab7adb6.addTo(map_7db7e329654cb4f2b06e52ebff2604f4);
#
#
#             var marker_f2dc25ded02e9729d59e9b4ef9f19cca = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_7db7e329654cb4f2b06e52ebff2604f4);
#
#
#         var popup_d5aa6790f2d29cbbee38e7282af125e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd1388fd7a023be1d74533ca186be7ca = $(`&lt;div id=&quot;html_dd1388fd7a023be1d74533ca186be7ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_d5aa6790f2d29cbbee38e7282af125e1.setContent(html_dd1388fd7a023be1d74533ca186be7ca);
#
#
#
#         marker_f2dc25ded02e9729d59e9b4ef9f19cca.bindPopup(popup_d5aa6790f2d29cbbee38e7282af125e1)
#         ;
#
#
#
#
#             var marker_96c179c379455d275b67df912c028401 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_7db7e329654cb4f2b06e52ebff2604f4);
#
#
#         var popup_fc97cc8029e6017fa2ffa2ce60d16613 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d5853de0959623950207d9139222612 = $(`&lt;div id=&quot;html_0d5853de0959623950207d9139222612&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_fc97cc8029e6017fa2ffa2ce60d16613.setContent(html_0d5853de0959623950207d9139222612);
#
#
#
#         marker_96c179c379455d275b67df912c028401.bindPopup(popup_fc97cc8029e6017fa2ffa2ce60d16613)
#         ;
#
#
#
#
#             var marker_0573b8236212819701295f9051dae329 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_7db7e329654cb4f2b06e52ebff2604f4);
#
#
#         var popup_d0a9a3cc353041fe7338bcb567ae6eff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4678e5bdfdd1590b3a6ce27832ce6375 = $(`&lt;div id=&quot;html_4678e5bdfdd1590b3a6ce27832ce6375&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_d0a9a3cc353041fe7338bcb567ae6eff.setContent(html_4678e5bdfdd1590b3a6ce27832ce6375);
#
#
#
#         marker_0573b8236212819701295f9051dae329.bindPopup(popup_d0a9a3cc353041fe7338bcb567ae6eff)
#         ;
#
#
#
#
#             var marker_0d870d980bbab91d44547773bfa4e737 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_7db7e329654cb4f2b06e52ebff2604f4);
#
#
#         var popup_5f984e162af2b96fda4d1a9dfe599c54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_179bfe7982d9169a37401b08177646fa = $(`&lt;div id=&quot;html_179bfe7982d9169a37401b08177646fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_5f984e162af2b96fda4d1a9dfe599c54.setContent(html_179bfe7982d9169a37401b08177646fa);
#
#
#
#         marker_0d870d980bbab91d44547773bfa4e737.bindPopup(popup_5f984e162af2b96fda4d1a9dfe599c54)
#         ;
#
#
#
#
#             var marker_5c54efa05e4f984680ea7a4fcc3f5b15 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_7db7e329654cb4f2b06e52ebff2604f4);
#
#
#         var popup_943ebcd2bb4c69b778342c50da30e913 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff216f3664bd03c44d2957e2328e14e7 = $(`&lt;div id=&quot;html_ff216f3664bd03c44d2957e2328e14e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_943ebcd2bb4c69b778342c50da30e913.setContent(html_ff216f3664bd03c44d2957e2328e14e7);
#
#
#
#         marker_5c54efa05e4f984680ea7a4fcc3f5b15.bindPopup(popup_943ebcd2bb4c69b778342c50da30e913)
#         ;
#
#
#
#
#             var marker_32af486542cbd9a95bea44c62af19bf2 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Darwin | 24.6.0
# Datetime: 2025-09-16 17:34:14
# Python Version: 3.11.13
# -----------------------------------
